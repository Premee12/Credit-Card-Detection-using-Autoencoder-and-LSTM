# %%
# import packages
# matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the  data points
TEST_PCT = 0.2 # 20% of the data

# %%
#set up Colour style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dac94e80b327> in <module>
#       3 LABELS = ["Normal","Fraud"]
#       4 col_list = ["cerulean","scarlet"]
# ----> 5 sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
#
# ~\Anaconda3\lib\site-packages\seaborn\rcmod.py in set(context, style, palette, font, font_scale, color_codes, rc)
#     119     set_context(context, font_scale)
#     120     set_style(style, rc={"font.family": font})
# --> 121     set_palette(palette, color_codes=color_codes)
#     122     if rc is not None:
#     123         mpl.rcParams.update(rc)
#
# ~\Anaconda3\lib\site-packages\seaborn\rcmod.py in set_palette(palette, n_colors, desat, color_codes)
#     547     if color_codes:
#     548         try:
# --> 549             palettes.set_color_codes(palette)
#     550         except ValueError:
#     551             pass
#
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in set_color_codes(palette)
#    1068         colors = [(0., 0., 1.), (0., .5, 0.), (1., 0., 0.), (.75, .75, 0.),
#    1069                   (.75, .75, 0.), (0., .75, .75), (0., 0., 0.)]
# -> 1070     elif palette in SEABORN_PALETTES:
#    1071         if not palette.endswith("6"):
#    1072             palette = palette + "6"
#
# TypeError: unhashable type: '_ColorPalette'

# %%
#Add CSV File
df = pd.read_csv("C:/Users/ACER/Desktop/Ayo programs/tm/creditcard.csv") #Make sure the CSV file is located in the same folder with this Code!
df.head(n=5) #just to check you imported the dataset properly
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#This section is used to confirm the data imported
df.shape #secondary check on the size of the dataframe
# Out:
# (284807, 31)

# %%
#check to see if any values are null, which there are not
df.isnull().values.any() #THe output should be False
# Out:
# False

# %%
#This section will give the output for Normal and Fraudulent rows of Data
pd.value_counts(df['Class'], sort = True) #class comparison 0=Normal 1=Fraud
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Balance of Data Visualization
#Visual confirmation of unbalanced Data in the Dataset
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(2), LABELS)
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
#Summary Statistics of the Transaction Amount Data
normal_df = df[df.Class == 0] #save normal_df observations into a separate df
fraud_df = df[df.Class == 1] #do the same for frauds

# %%
#Description of Differences btw the Normal and Fraud data
normal_df.Amount.describe() #For Normal
fraud_df.Amount.describe() #For Fraud
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#Visual Exploration of the Transaction Amount Data
#plot of high value transactions
bins = np.linspace(200, 2500, 100)
plt.hist(normal_df.Amount, bins, alpha=1, density=True, label='Normal')
plt.hist(fraud_df.Amount, bins, alpha=0.6, density=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Amount by percentage of transactions (transactions \$200+)")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions (%)");
plt.show()

# %%
#Visual Exploration of the Data by Hour
bins = np.linspace(0, 48, 48) #48 hours
plt.hist((normal_df.Time/(60*60)), bins, alpha=1, density=True, label='Normal')
plt.hist((fraud_df.Time/(60*60)), bins, alpha=0.6, density=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Percentage of transactions by hour")
plt.xlabel("Transaction time as measured from first transaction in the dataset (hours)")
plt.ylabel("Percentage of transactions (%)");
#plt.hist((df.Time/(60*60)),bins)
plt.show()

# %%
#Visual Exploration of Transaction Amount vs. Hour
plt.scatter((normal_df.Time/(60*60)), normal_df.Amount, alpha=0.6, label='Normal')
plt.scatter((fraud_df.Time/(60*60)), fraud_df.Amount, alpha=0.9, label='Fraud')
plt.title("Amount of transaction by hour")
plt.xlabel("Transaction time as measured from first transaction in the dataset (hours)")
plt.ylabel('Amount (USD)')
plt.legend(loc='upper right')
plt.show()

# %%
#Model Setup: Basic Autoencoder

#Normalize and Scale Data
data = df.drop(['Time'], axis=1) #if you think the var is unimportant
df_norm = df
df_norm['Time'] = StandardScaler().fit_transform(df_norm['Time'].values.reshape(-1, 1))
df_norm['Amount'] = StandardScaler().fit_transform(df_norm['Amount'].values.reshape(-1, 1))

# %%
#Dividing Training and Test Set
train_x, test_x = train_test_split(df_norm, test_size=TEST_PCT, random_state=RANDOM_SEED)
train_x = train_x[train_x.Class == 0] #where normal transactions
train_x = train_x.drop(['Class'], axis=1) #drop the class column

# %%
# TEST
test_y = test_x['Class'] #save the class column for the test set
test_x = test_x.drop(['Class'], axis=1) #drop the class column

# %%
# TRAIN 
train_x = train_x.values #transform to ndarray
test_x = test_x.values

# %%
#confirming the new ndarray is the expected shape
train_x.shape
# Out:
# (227468, 30)

# %%
#Creating the Model
#Autoencoder Layer Structure and Parameters
nb_epoch = 100
batch_size = 128
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim = int(encoding_dim / 2) #i.e. 7
learning_rate = 1e-7

# %%
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
#Model Training and Logging
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

# %%
cp = ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               save_best_only=True,
                               verbose=0)

# %%
tb = TensorBoard(log_dir='./logs',
                histogram_freq=0,
                write_graph=True,
                write_images=True)

# %%
history = autoencoder.fit(train_x, train_x,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_x, test_x),
                    verbose=1,
                    callbacks=[cp, tb]).history
# Out:
# WARNING:tensorflow:From C:\Users\ACER\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 227468 samples, validate on 56962 samples
# WARNING:tensorflow:From C:\Users\ACER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\ACER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 227468/227468 [==============================] - 13s 57us/step - loss: 0.8629 - accuracy: 0.4845 - val_loss: 0.8354 - val_accuracy: 0.5873
# WARNING:tensorflow:From C:\Users\ACER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
# 227468/227468 [==============================] - 12s 54us/step - loss: 0.7833 - accuracy: 0.6047 - val_loss: 0.8012 - val_accuracy: 0.6214
# Epoch 3/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.7547 - accuracy: 0.6367 - val_loss: 0.7774 - val_accuracy: 0.6439
# Epoch 4/100
# 227468/227468 [==============================] - 12s 55us/step - loss: 0.7378 - accuracy: 0.6483 - val_loss: 0.7663 - val_accuracy: 0.6480
# Epoch 5/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.7292 - accuracy: 0.6526 - val_loss: 0.7588 - val_accuracy: 0.6538
# Epoch 6/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.7240 - accuracy: 0.6586 - val_loss: 0.7564 - val_accuracy: 0.6566
# Epoch 7/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.7208 - accuracy: 0.6637 - val_loss: 0.7521 - val_accuracy: 0.6649
# Epoch 8/100
# 227468/227468 [==============================] - 13s 58us/step - loss: 0.7180 - accuracy: 0.6676 - val_loss: 0.7493 - val_accuracy: 0.6616
# Epoch 9/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.7154 - accuracy: 0.6688 - val_loss: 0.7482 - val_accuracy: 0.6687
# Epoch 10/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.7136 - accuracy: 0.6699 - val_loss: 0.7466 - val_accuracy: 0.6636
# Epoch 11/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.7122 - accuracy: 0.6704 - val_loss: 0.7447 - val_accuracy: 0.6713
# Epoch 12/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.7112 - accuracy: 0.6714 - val_loss: 0.7438 - val_accuracy: 0.6708
# Epoch 13/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7102 - accuracy: 0.6725 - val_loss: 0.7428 - val_accuracy: 0.6742
# Epoch 14/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.7094 - accuracy: 0.6728 - val_loss: 0.7440 - val_accuracy: 0.6688
# Epoch 15/100
# 227468/227468 [==============================] - 12s 55us/step - loss: 0.7086 - accuracy: 0.6733 - val_loss: 0.7425 - val_accuracy: 0.6710
# Epoch 16/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.7079 - accuracy: 0.6740 - val_loss: 0.7418 - val_accuracy: 0.6727
# Epoch 17/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.7076 - accuracy: 0.6745 - val_loss: 0.7408 - val_accuracy: 0.6734
# Epoch 18/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.7068 - accuracy: 0.6756 - val_loss: 0.7400 - val_accuracy: 0.6730
# Epoch 19/100
# 227468/227468 [==============================] - 12s 54us/step - loss: 0.7065 - accuracy: 0.6756 - val_loss: 0.7408 - val_accuracy: 0.6754
# Epoch 20/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.7060 - accuracy: 0.6766 - val_loss: 0.7401 - val_accuracy: 0.6792
# Epoch 21/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7060 - accuracy: 0.6757 - val_loss: 0.7398 - val_accuracy: 0.6739
# Epoch 22/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7056 - accuracy: 0.6769 - val_loss: 0.7383 - val_accuracy: 0.6771
# Epoch 23/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7052 - accuracy: 0.6769 - val_loss: 0.7386 - val_accuracy: 0.6773
# Epoch 24/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7049 - accuracy: 0.6771 - val_loss: 0.7379 - val_accuracy: 0.6737
# Epoch 25/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7046 - accuracy: 0.6776 - val_loss: 0.7389 - val_accuracy: 0.6729
# Epoch 26/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7044 - accuracy: 0.6778 - val_loss: 0.7370 - val_accuracy: 0.6798
# Epoch 27/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7041 - accuracy: 0.6772 - val_loss: 0.7380 - val_accuracy: 0.6750
# Epoch 28/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7043 - accuracy: 0.6780 - val_loss: 0.7371 - val_accuracy: 0.6777
# Epoch 29/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7036 - accuracy: 0.6789 - val_loss: 0.7386 - val_accuracy: 0.6797
# Epoch 30/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7034 - accuracy: 0.6791 - val_loss: 0.7363 - val_accuracy: 0.6813
# Epoch 31/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.7031 - accuracy: 0.6802 - val_loss: 0.7373 - val_accuracy: 0.6788
# Epoch 32/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7031 - accuracy: 0.6798 - val_loss: 0.7374 - val_accuracy: 0.6772
# Epoch 33/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7031 - accuracy: 0.6806 - val_loss: 0.7374 - val_accuracy: 0.6737
# Epoch 34/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7028 - accuracy: 0.6806 - val_loss: 0.7365 - val_accuracy: 0.6777
# Epoch 35/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7029 - accuracy: 0.6809 - val_loss: 0.7369 - val_accuracy: 0.6796
# Epoch 36/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7026 - accuracy: 0.6810 - val_loss: 0.7366 - val_accuracy: 0.6784
# Epoch 37/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7025 - accuracy: 0.6808 - val_loss: 0.7367 - val_accuracy: 0.6750
# Epoch 38/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.7023 - accuracy: 0.6807 - val_loss: 0.7354 - val_accuracy: 0.6795
# Epoch 39/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7022 - accuracy: 0.6814 - val_loss: 0.7356 - val_accuracy: 0.6791
# Epoch 40/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7019 - accuracy: 0.6822 - val_loss: 0.7347 - val_accuracy: 0.6804
# Epoch 41/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7020 - accuracy: 0.6826 - val_loss: 0.7353 - val_accuracy: 0.6799
# Epoch 42/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7017 - accuracy: 0.6826 - val_loss: 0.7355 - val_accuracy: 0.6774
# Epoch 43/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.7015 - accuracy: 0.6825 - val_loss: 0.7366 - val_accuracy: 0.6763
# Epoch 44/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7014 - accuracy: 0.6834 - val_loss: 0.7353 - val_accuracy: 0.6788
# Epoch 45/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7014 - accuracy: 0.6830 - val_loss: 0.7344 - val_accuracy: 0.6805
# Epoch 46/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7012 - accuracy: 0.6834 - val_loss: 0.7345 - val_accuracy: 0.6825
# Epoch 47/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7010 - accuracy: 0.6832 - val_loss: 0.7347 - val_accuracy: 0.6813
# Epoch 48/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7008 - accuracy: 0.6844 - val_loss: 0.7346 - val_accuracy: 0.6777
# Epoch 49/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.7008 - accuracy: 0.6840 - val_loss: 0.7351 - val_accuracy: 0.6806
# Epoch 50/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.7008 - accuracy: 0.6841 - val_loss: 0.7337 - val_accuracy: 0.6821
# Epoch 51/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.7007 - accuracy: 0.6843 - val_loss: 0.7338 - val_accuracy: 0.6831
# Epoch 52/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.7004 - accuracy: 0.6852 - val_loss: 0.7342 - val_accuracy: 0.6836
# Epoch 53/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.7004 - accuracy: 0.6851 - val_loss: 0.7354 - val_accuracy: 0.6828
# Epoch 54/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7002 - accuracy: 0.6853 - val_loss: 0.7338 - val_accuracy: 0.6821
# Epoch 55/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.7000 - accuracy: 0.6856 - val_loss: 0.7332 - val_accuracy: 0.6865
# Epoch 56/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.7003 - accuracy: 0.6861 - val_loss: 0.7330 - val_accuracy: 0.6808
# Epoch 57/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.7000 - accuracy: 0.6865 - val_loss: 0.7333 - val_accuracy: 0.6850
# Epoch 58/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6999 - accuracy: 0.6861 - val_loss: 0.7337 - val_accuracy: 0.6843
# Epoch 59/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6998 - accuracy: 0.6864 - val_loss: 0.7342 - val_accuracy: 0.6840
# Epoch 60/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.6999 - accuracy: 0.6869 - val_loss: 0.7329 - val_accuracy: 0.6870
# Epoch 61/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6996 - accuracy: 0.6872 - val_loss: 0.7335 - val_accuracy: 0.6891
# Epoch 62/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6995 - accuracy: 0.6874 - val_loss: 0.7331 - val_accuracy: 0.6882
# Epoch 63/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6996 - accuracy: 0.6873 - val_loss: 0.7337 - val_accuracy: 0.6881
# Epoch 64/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6996 - accuracy: 0.6880 - val_loss: 0.7323 - val_accuracy: 0.6874
# Epoch 65/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6992 - accuracy: 0.6879 - val_loss: 0.7334 - val_accuracy: 0.6867
# Epoch 66/100
# 227468/227468 [==============================] - 4s 19us/step - loss: 0.6995 - accuracy: 0.6879 - val_loss: 0.7328 - val_accuracy: 0.6891
# Epoch 67/100
# 227468/227468 [==============================] - 5s 23us/step - loss: 0.6993 - accuracy: 0.6882 - val_loss: 0.7331 - val_accuracy: 0.6893
# Epoch 68/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6994 - accuracy: 0.6885 - val_loss: 0.7321 - val_accuracy: 0.6889
# Epoch 69/100
# 227468/227468 [==============================] - 5s 20us/step - loss: 0.6992 - accuracy: 0.6881 - val_loss: 0.7330 - val_accuracy: 0.6870
# Epoch 70/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6995 - accuracy: 0.6880 - val_loss: 0.7334 - val_accuracy: 0.6841
# Epoch 71/100
# 227468/227468 [==============================] - 5s 20us/step - loss: 0.6996 - accuracy: 0.6883 - val_loss: 0.7351 - val_accuracy: 0.6839
# Epoch 72/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6992 - accuracy: 0.6884 - val_loss: 0.7322 - val_accuracy: 0.6906
# Epoch 73/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6989 - accuracy: 0.6886 - val_loss: 0.7332 - val_accuracy: 0.6774
# Epoch 74/100
# 227468/227468 [==============================] - 5s 20us/step - loss: 0.6990 - accuracy: 0.6880 - val_loss: 0.7331 - val_accuracy: 0.6891
# Epoch 75/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6987 - accuracy: 0.6892 - val_loss: 0.7327 - val_accuracy: 0.6864
# Epoch 76/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6989 - accuracy: 0.6888 - val_loss: 0.7345 - val_accuracy: 0.6793
# Epoch 77/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6989 - accuracy: 0.6889 - val_loss: 0.7345 - val_accuracy: 0.6862
# Epoch 78/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6990 - accuracy: 0.6888 - val_loss: 0.7324 - val_accuracy: 0.6859
# Epoch 79/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6990 - accuracy: 0.6884 - val_loss: 0.7322 - val_accuracy: 0.6876
# Epoch 80/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6987 - accuracy: 0.6886 - val_loss: 0.7324 - val_accuracy: 0.6838
# Epoch 81/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6987 - accuracy: 0.6890 - val_loss: 0.7328 - val_accuracy: 0.6843
# Epoch 82/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6988 - accuracy: 0.6888 - val_loss: 0.7326 - val_accuracy: 0.6907
# Epoch 83/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6989 - accuracy: 0.6887 - val_loss: 0.7329 - val_accuracy: 0.6908
# Epoch 84/100
# 227468/227468 [==============================] - 11s 51us/step - loss: 0.6985 - accuracy: 0.6887 - val_loss: 0.7339 - val_accuracy: 0.6765
# Epoch 85/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6986 - accuracy: 0.6890 - val_loss: 0.7347 - val_accuracy: 0.6850
# Epoch 86/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6987 - accuracy: 0.6890 - val_loss: 0.7326 - val_accuracy: 0.6809
# Epoch 87/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.6984 - accuracy: 0.6890 - val_loss: 0.7323 - val_accuracy: 0.6841
# Epoch 88/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6984 - accuracy: 0.6891 - val_loss: 0.7319 - val_accuracy: 0.6945
# Epoch 89/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6985 - accuracy: 0.6890 - val_loss: 0.7320 - val_accuracy: 0.6888
# Epoch 90/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6982 - accuracy: 0.6896 - val_loss: 0.7318 - val_accuracy: 0.6874
# Epoch 91/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.6985 - accuracy: 0.6898 - val_loss: 0.7312 - val_accuracy: 0.6889
# Epoch 92/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6982 - accuracy: 0.6901 - val_loss: 0.7322 - val_accuracy: 0.6869
# Epoch 93/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6982 - accuracy: 0.6906 - val_loss: 0.7313 - val_accuracy: 0.6885
# Epoch 94/100
# 227468/227468 [==============================] - 12s 54us/step - loss: 0.6983 - accuracy: 0.6904 - val_loss: 0.7326 - val_accuracy: 0.6908
# Epoch 95/100
# 227468/227468 [==============================] - 15s 66us/step - loss: 0.6981 - accuracy: 0.6902 - val_loss: 0.7313 - val_accuracy: 0.6900
# Epoch 96/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6980 - accuracy: 0.6903 - val_loss: 0.7313 - val_accuracy: 0.6872
# Epoch 97/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6981 - accuracy: 0.6908 - val_loss: 0.7316 - val_accuracy: 0.6891
# Epoch 98/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.6978 - accuracy: 0.6902 - val_loss: 0.7312 - val_accuracy: 0.6899
# Epoch 99/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6979 - accuracy: 0.6903 - val_loss: 0.7308 - val_accuracy: 0.6907
# Epoch 100/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6981 - accuracy: 0.6899 - val_loss: 0.7308 - val_accuracy: 0.6881

# %%
#Creating the Model
#Autoencoder Layer Structure and Parameters
nb_epoch = 100
batch_size = 128
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim = int(encoding_dim / 2) #i.e. 7
learning_rate = 1e-7

input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
#confirming the new ndarray is the expected shape
train_x.shape
# Out:
# (227468, 30)

# %%
#confirming the new ndarray is the expected shape
train_x.shape
# Out:
# (227468, 30)
