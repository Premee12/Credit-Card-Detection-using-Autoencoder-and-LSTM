# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-982db6fa57ec> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from scipy import stats
#       4 import tensorflow as tf
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-982db6fa57ec> in <module>
#       2 import numpy as np
#       3 from scipy import stats
# ----> 4 import tensorflow as tf
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\USER\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-982db6fa57ec> in <module>
#       4 import tensorflow as tf
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#       7 import pickle
#       8 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-982db6fa57ec> in <module>
#       6 import seaborn as sns
#       7 import pickle
# ----> 8 from sklearn.model_selection import train_test_split
#       9 from sklearn.metrics import confusion_matrix, precision_recall_curve
#      10 from sklearn.metrics import recall_score, classification_report, auc, roc_curve
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-982db6fa57ec> in <module>
#      12 from sklearn.preprocessing import StandardScaler
#      13 from pylab import rcParams
# ---> 14 from keras.models import Model, load_model
#      15 from keras.layers import Input, Dense
#      16 from keras.callbacks import ModelCheckpoint, TensorBoard
#
# ModuleNotFoundError: No module named 'keras'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#set random seed and percentage of test data
RANDOM_SEED = 314 #used to help randomly select the data points
TEST_PCT = 0.2 # 20% of the data

#set up graphic style
rcParams['figure.figsize'] = 14, 8.7 # Golden Mean
LABELS = ["Normal","Fraud"]
col_list = ["cerulean","scarlet"]
sns.set(style='white', font_scale=1.75, palette=sns.xkcd_palette(col_list))
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("creditcard.csv") #unzip and read in data downloaded to the local directory
df.head(n=5) #just to check you imported the dataset properly
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape #secondary check on the size of the dataframe
# Out:
# (284807, 31)

# %%
df.isnull().values.any() #check to see if any values are null, which there are not
# Out:
# False

# %%
pd.value_counts(df['Class'], sort = True) #class comparison 0=Normal 1=Fraud
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.xticks(range(2), LABELS)
plt.title("Frequency by observation number")
plt.xlabel("Class")
plt.ylabel("Number of Observations");

# %%
normal_df = df[df.Class == 0] #save normal_df observations into a separate df
fraud_df = df[df.Class == 1] #do the same for frauds

# %%
normal_df.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_df.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#plot of high value transactions
bins = np.linspace(200, 2500, 100)
plt.hist(normal_df.Amount, bins, alpha=1, normed=True, label='Normal')
plt.hist(fraud_df.Amount, bins, alpha=0.6, normed=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Amount by percentage of transactions (transactions \$200+)")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions (%)");
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6c798662f9d3> in <module>
#       1 #plot of high value transactions
#       2 bins = np.linspace(200, 2500, 100)
# ----> 3 plt.hist(normal_df.Amount, bins, alpha=1, normed=True, label='Normal')
#       4 plt.hist(fraud_df.Amount, bins, alpha=0.6, normed=True, label='Fraud')
#       5 plt.legend(loc='upper right')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2688
#    2689
# -> 2690 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#    2691 @_copy_docstring_and_deprecators(Axes.hlines)
#    2692 def hlines(
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6818             return tops, bins, cbook.silent_list(patch_type, patches)
#    6819
# -> 6820     @_preprocess_data(replace_names=["x", "y", "weights"])
#    6821     @docstring.dedent_interpd
#    6822     def hist2d(self, x, y, bins=10, range=None, density=False, weights=None,
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
bins = np.linspace(0, 48, 48) #48 hours
plt.hist((normal_df.Time/(60*60)), bins, alpha=1, normed=True, label='Normal')
plt.hist((fraud_df.Time/(60*60)), bins, alpha=0.6, normed=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Percentage of transactions by hour")
plt.xlabel("Transaction time as measured from first transaction in the dataset (hours)")
plt.ylabel("Percentage of transactions (%)");
#plt.hist((df.Time/(60*60)),bins)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7cbdbc7aa9e3> in <module>
#       1 bins = np.linspace(0, 48, 48) #48 hours
# ----> 2 plt.hist((normal_df.Time/(60*60)), bins, alpha=1, normed=True, label='Normal')
#       3 plt.hist((fraud_df.Time/(60*60)), bins, alpha=0.6, normed=True, label='Fraud')
#       4 plt.legend(loc='upper right')
#       5 plt.title("Percentage of transactions by hour")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2688
#    2689
# -> 2690 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#    2691 @_copy_docstring_and_deprecators(Axes.hlines)
#    2692 def hlines(
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6818             return tops, bins, cbook.silent_list(patch_type, patches)
#    6819
# -> 6820     @_preprocess_data(replace_names=["x", "y", "weights"])
#    6821     @docstring.dedent_interpd
#    6822     def hist2d(self, x, y, bins=10, range=None, density=False, weights=None,
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
plt.scatter((normal_df.Time/(60*60)), normal_df.Amount, alpha=0.6, label='Normal')
plt.scatter((fraud_df.Time/(60*60)), fraud_df.Amount, alpha=0.9, label='Fraud')
plt.title("Amount of transaction by hour")
plt.xlabel("Transaction time as measured from first transaction in the dataset (hours)")
plt.ylabel('Amount (USD)')
plt.legend(loc='upper right')
plt.show()

# %%
#data = df.drop(['Time'], axis=1) #if you think the var is unimportant
df_norm = df
df_norm['Time'] = StandardScaler().fit_transform(df_norm['Time'].values.reshape(-1, 1))
df_norm['Amount'] = StandardScaler().fit_transform(df_norm['Amount'].values.reshape(-1, 1))

# %%
train_x, test_x = train_test_split(df_norm, test_size=TEST_PCT, random_state=RANDOM_SEED)
train_x = train_x[train_x.Class == 0] #where normal transactions
train_x = train_x.drop(['Class'], axis=1) #drop the class column


test_y = test_x['Class'] #save the class column for the test set
test_x = test_x.drop(['Class'], axis=1) #drop the class column

train_x = train_x.values #transform to ndarray
test_x = test_x.values

# %%
train_x.shape
# Out:
# (227468, 30)

# %%
nb_epoch = 100
batch_size = 128
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 14
hidden_dim = int(encoding_dim / 2) #i.e. 7
learning_rate = 1e-7

input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

cp = ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               save_best_only=True,
                               verbose=0)

tb = TensorBoard(log_dir='./logs',
                histogram_freq=0,
                write_graph=True,
                write_images=True)

history = autoencoder.fit(train_x, train_x,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_x, test_x),
                    verbose=1,
                    callbacks=[cp, tb]).history
# Out:
# WARNING:tensorflow:From C:\Users\USER\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 227468 samples, validate on 56962 samples
# WARNING:tensorflow:From C:\Users\USER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\USER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.8491 - accuracy: 0.5145 - val_loss: 0.8131 - val_accuracy: 0.6065
# WARNING:tensorflow:From C:\Users\USER\Anaconda3\lib\site-packages\keras\callbacks\tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.7603 - accuracy: 0.6254 - val_loss: 0.7788 - val_accuracy: 0.6383
# Epoch 3/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.7383 - accuracy: 0.6525 - val_loss: 0.7646 - val_accuracy: 0.6576
# Epoch 4/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.7271 - accuracy: 0.6634 - val_loss: 0.7563 - val_accuracy: 0.6633
# Epoch 5/100
# 227468/227468 [==============================] - 7s 29us/step - loss: 0.7200 - accuracy: 0.6672 - val_loss: 0.7506 - val_accuracy: 0.6706
# Epoch 6/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.7154 - accuracy: 0.6732 - val_loss: 0.7485 - val_accuracy: 0.6739
# Epoch 7/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.7117 - accuracy: 0.6796 - val_loss: 0.7434 - val_accuracy: 0.6816
# Epoch 8/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.7092 - accuracy: 0.6849 - val_loss: 0.7414 - val_accuracy: 0.6894
# Epoch 9/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.7068 - accuracy: 0.6907 - val_loss: 0.7390 - val_accuracy: 0.6952
# Epoch 10/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.7051 - accuracy: 0.6942 - val_loss: 0.7381 - val_accuracy: 0.6910
# Epoch 11/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.7036 - accuracy: 0.6951 - val_loss: 0.7376 - val_accuracy: 0.6991
# Epoch 12/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.7025 - accuracy: 0.6960 - val_loss: 0.7369 - val_accuracy: 0.7032
# Epoch 13/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.7014 - accuracy: 0.6962 - val_loss: 0.7359 - val_accuracy: 0.6971
# Epoch 14/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.7004 - accuracy: 0.6965 - val_loss: 0.7348 - val_accuracy: 0.6963
# Epoch 15/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6994 - accuracy: 0.6984 - val_loss: 0.7365 - val_accuracy: 0.7006
# Epoch 16/100
# 227468/227468 [==============================] - 6s 28us/step - loss: 0.6985 - accuracy: 0.6982 - val_loss: 0.7325 - val_accuracy: 0.6984
# Epoch 17/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.6979 - accuracy: 0.6981 - val_loss: 0.7314 - val_accuracy: 0.7007
# Epoch 18/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6971 - accuracy: 0.6970 - val_loss: 0.7316 - val_accuracy: 0.6920
# Epoch 19/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6965 - accuracy: 0.6972 - val_loss: 0.7307 - val_accuracy: 0.6969
# Epoch 20/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6961 - accuracy: 0.6964 - val_loss: 0.7317 - val_accuracy: 0.7002
# Epoch 21/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6956 - accuracy: 0.6969 - val_loss: 0.7292 - val_accuracy: 0.6966
# Epoch 22/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6951 - accuracy: 0.6966 - val_loss: 0.7288 - val_accuracy: 0.6976
# Epoch 23/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6948 - accuracy: 0.6968 - val_loss: 0.7285 - val_accuracy: 0.6955
# Epoch 24/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6945 - accuracy: 0.6963 - val_loss: 0.7291 - val_accuracy: 0.6996
# Epoch 25/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6942 - accuracy: 0.6970 - val_loss: 0.7284 - val_accuracy: 0.7043
# Epoch 26/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6939 - accuracy: 0.6972 - val_loss: 0.7278 - val_accuracy: 0.7000
# Epoch 27/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6935 - accuracy: 0.6975 - val_loss: 0.7302 - val_accuracy: 0.6943
# Epoch 28/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6936 - accuracy: 0.6964 - val_loss: 0.7271 - val_accuracy: 0.7028
# Epoch 29/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.6931 - accuracy: 0.6973 - val_loss: 0.7266 - val_accuracy: 0.7028
# Epoch 30/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6931 - accuracy: 0.6971 - val_loss: 0.7264 - val_accuracy: 0.7008
# Epoch 31/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6929 - accuracy: 0.6978 - val_loss: 0.7275 - val_accuracy: 0.6973
# Epoch 32/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6928 - accuracy: 0.6979 - val_loss: 0.7263 - val_accuracy: 0.7031
# Epoch 33/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6925 - accuracy: 0.6979 - val_loss: 0.7275 - val_accuracy: 0.7023
# Epoch 34/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6928 - accuracy: 0.6973 - val_loss: 0.7268 - val_accuracy: 0.6979
# Epoch 35/100
# 227468/227468 [==============================] - 7s 31us/step - loss: 0.6923 - accuracy: 0.6978 - val_loss: 0.7258 - val_accuracy: 0.7011
# Epoch 36/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6925 - accuracy: 0.6983 - val_loss: 0.7263 - val_accuracy: 0.6974
# Epoch 37/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6920 - accuracy: 0.6985 - val_loss: 0.7280 - val_accuracy: 0.6981
# Epoch 38/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6921 - accuracy: 0.6985 - val_loss: 0.7259 - val_accuracy: 0.7019
# Epoch 39/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.6921 - accuracy: 0.6983 - val_loss: 0.7261 - val_accuracy: 0.6992
# Epoch 40/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6919 - accuracy: 0.6987 - val_loss: 0.7313 - val_accuracy: 0.6975
# Epoch 41/100
# 227468/227468 [==============================] - 8s 33us/step - loss: 0.6917 - accuracy: 0.6988 - val_loss: 0.7251 - val_accuracy: 0.7015
# Epoch 42/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6920 - accuracy: 0.6983 - val_loss: 0.7251 - val_accuracy: 0.6995
# Epoch 43/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6916 - accuracy: 0.6998 - val_loss: 0.7260 - val_accuracy: 0.7013
# Epoch 44/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6914 - accuracy: 0.6997 - val_loss: 0.7251 - val_accuracy: 0.7019
# Epoch 45/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6914 - accuracy: 0.7001 - val_loss: 0.7258 - val_accuracy: 0.7015
# Epoch 46/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6913 - accuracy: 0.6997 - val_loss: 0.7244 - val_accuracy: 0.7034
# Epoch 47/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6915 - accuracy: 0.6999 - val_loss: 0.7261 - val_accuracy: 0.6955
# Epoch 48/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6911 - accuracy: 0.7001 - val_loss: 0.7249 - val_accuracy: 0.7031
# Epoch 49/100
# 227468/227468 [==============================] - 13s 59us/step - loss: 0.6912 - accuracy: 0.7000 - val_loss: 0.7257 - val_accuracy: 0.6999
# Epoch 50/100
# 227468/227468 [==============================] - 13s 58us/step - loss: 0.6911 - accuracy: 0.7005 - val_loss: 0.7255 - val_accuracy: 0.7039
# Epoch 51/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6909 - accuracy: 0.7016 - val_loss: 0.7259 - val_accuracy: 0.7011
# Epoch 52/100
# 227468/227468 [==============================] - 12s 55us/step - loss: 0.6909 - accuracy: 0.7009 - val_loss: 0.7242 - val_accuracy: 0.7038
# Epoch 53/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.6909 - accuracy: 0.7017 - val_loss: 0.7249 - val_accuracy: 0.7061
# Epoch 54/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6908 - accuracy: 0.7009 - val_loss: 0.7243 - val_accuracy: 0.7035
# Epoch 55/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6908 - accuracy: 0.7016 - val_loss: 0.7242 - val_accuracy: 0.7005
# Epoch 56/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6907 - accuracy: 0.7012 - val_loss: 0.7250 - val_accuracy: 0.7000
# Epoch 57/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6907 - accuracy: 0.7012 - val_loss: 0.7241 - val_accuracy: 0.6999
# Epoch 58/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6904 - accuracy: 0.7015 - val_loss: 0.7241 - val_accuracy: 0.7045
# Epoch 59/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6909 - accuracy: 0.7023 - val_loss: 0.7237 - val_accuracy: 0.7023
# Epoch 60/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6902 - accuracy: 0.7013 - val_loss: 0.7248 - val_accuracy: 0.7051
# Epoch 61/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6904 - accuracy: 0.7024 - val_loss: 0.7239 - val_accuracy: 0.7056
# Epoch 62/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6902 - accuracy: 0.7021 - val_loss: 0.7279 - val_accuracy: 0.7026
# Epoch 63/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6904 - accuracy: 0.7026 - val_loss: 0.7254 - val_accuracy: 0.6959
# Epoch 64/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6902 - accuracy: 0.7024 - val_loss: 0.7240 - val_accuracy: 0.7070
# Epoch 65/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6900 - accuracy: 0.7030 - val_loss: 0.7266 - val_accuracy: 0.7027
# Epoch 66/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6902 - accuracy: 0.7026 - val_loss: 0.7240 - val_accuracy: 0.7028
# Epoch 67/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6899 - accuracy: 0.7019 - val_loss: 0.7263 - val_accuracy: 0.6992
# Epoch 68/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6897 - accuracy: 0.7028 - val_loss: 0.7247 - val_accuracy: 0.7007
# Epoch 69/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6896 - accuracy: 0.7033 - val_loss: 0.7240 - val_accuracy: 0.6985
# Epoch 70/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6897 - accuracy: 0.7037 - val_loss: 0.7235 - val_accuracy: 0.7057
# Epoch 71/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6894 - accuracy: 0.7035 - val_loss: 0.7251 - val_accuracy: 0.6984
# Epoch 72/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6895 - accuracy: 0.7034 - val_loss: 0.7243 - val_accuracy: 0.6979
# Epoch 73/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6894 - accuracy: 0.7051 - val_loss: 0.7306 - val_accuracy: 0.6927
# Epoch 74/100
# 227468/227468 [==============================] - 12s 55us/step - loss: 0.6890 - accuracy: 0.7045 - val_loss: 0.7284 - val_accuracy: 0.7032
# Epoch 75/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6893 - accuracy: 0.7038 - val_loss: 0.7229 - val_accuracy: 0.7031
# Epoch 76/100
# 227468/227468 [==============================] - 6s 27us/step - loss: 0.6892 - accuracy: 0.7052 - val_loss: 0.7231 - val_accuracy: 0.7043
# Epoch 77/100
# 227468/227468 [==============================] - 6s 28us/step - loss: 0.6890 - accuracy: 0.7047 - val_loss: 0.7247 - val_accuracy: 0.7034
# Epoch 78/100
# 227468/227468 [==============================] - 4800s 21ms/step - loss: 0.6892 - accuracy: 0.7051 - val_loss: 0.7250 - val_accuracy: 0.6981
# Epoch 79/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6890 - accuracy: 0.7055 - val_loss: 0.7248 - val_accuracy: 0.7024
# Epoch 80/100
# 227468/227468 [==============================] - 5s 21us/step - loss: 0.6890 - accuracy: 0.7053 - val_loss: 0.7245 - val_accuracy: 0.7063
# Epoch 81/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6887 - accuracy: 0.7062 - val_loss: 0.7236 - val_accuracy: 0.7006
# Epoch 82/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6887 - accuracy: 0.7061 - val_loss: 0.7233 - val_accuracy: 0.7072
# Epoch 83/100
# 227468/227468 [==============================] - 3s 13us/step - loss: 0.6887 - accuracy: 0.7071 - val_loss: 0.7236 - val_accuracy: 0.7097
# Epoch 84/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6885 - accuracy: 0.7066 - val_loss: 0.7238 - val_accuracy: 0.7036
# Epoch 85/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6886 - accuracy: 0.7072 - val_loss: 0.7242 - val_accuracy: 0.7062
# Epoch 86/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6884 - accuracy: 0.7068 - val_loss: 0.7234 - val_accuracy: 0.7076
# Epoch 87/100
# 227468/227468 [==============================] - 3s 13us/step - loss: 0.6883 - accuracy: 0.7073 - val_loss: 0.7238 - val_accuracy: 0.7026
# Epoch 88/100
# 227468/227468 [==============================] - 3s 12us/step - loss: 0.6883 - accuracy: 0.7080 - val_loss: 0.7235 - val_accuracy: 0.7069
# Epoch 89/100
# 227468/227468 [==============================] - 3s 15us/step - loss: 0.6887 - accuracy: 0.7082 - val_loss: 0.7231 - val_accuracy: 0.7113
# Epoch 90/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6882 - accuracy: 0.7083 - val_loss: 0.7244 - val_accuracy: 0.7091
# Epoch 91/100
# 227468/227468 [==============================] - 4s 16us/step - loss: 0.6881 - accuracy: 0.7083 - val_loss: 0.7269 - val_accuracy: 0.6989
# Epoch 92/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6881 - accuracy: 0.7077 - val_loss: 0.7231 - val_accuracy: 0.7022
# Epoch 93/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6881 - accuracy: 0.7084 - val_loss: 0.7231 - val_accuracy: 0.7088
# Epoch 94/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6880 - accuracy: 0.7089 - val_loss: 0.7226 - val_accuracy: 0.7111
# Epoch 95/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6878 - accuracy: 0.7084 - val_loss: 0.7237 - val_accuracy: 0.7048
# Epoch 96/100
# 227468/227468 [==============================] - 3s 13us/step - loss: 0.6880 - accuracy: 0.7099 - val_loss: 0.7268 - val_accuracy: 0.7008
# Epoch 97/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6881 - accuracy: 0.7088 - val_loss: 0.7222 - val_accuracy: 0.7106
# Epoch 98/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6879 - accuracy: 0.7083 - val_loss: 0.7237 - val_accuracy: 0.7064
# Epoch 99/100
# 227468/227468 [==============================] - 3s 14us/step - loss: 0.6876 - accuracy: 0.7089 - val_loss: 0.7229 - val_accuracy: 0.7070
# Epoch 100/100
# 227468/227468 [==============================] - 4s 17us/step - loss: 0.6879 - accuracy: 0.7090 - val_loss: 0.7223 - val_accuracy: 0.7078

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

cp = ModelCheckpoint(filepath="autoencoder_fraud.h5",
                               save_best_only=True,
                               verbose=0)

tb = TensorBoard(log_dir='./logs',
                histogram_freq=0,
                write_graph=True,
                write_images=True)

history = autoencoder.fit(train_x, train_x,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(test_x, test_x),
                    verbose=1,
                    callbacks=[cp, tb]).history
# Out:
# Train on 227468 samples, validate on 56962 samples
# Epoch 1/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6875 - accuracy: 0.7089 - val_loss: 0.7238 - val_accuracy: 0.7054
# Epoch 2/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6880 - accuracy: 0.7087 - val_loss: 0.7226 - val_accuracy: 0.7042
# Epoch 3/100
# 227468/227468 [==============================] - 14s 60us/step - loss: 0.6876 - accuracy: 0.7094 - val_loss: 0.7230 - val_accuracy: 0.7014
# Epoch 4/100
# 227468/227468 [==============================] - 13s 57us/step - loss: 0.6875 - accuracy: 0.7093 - val_loss: 0.7239 - val_accuracy: 0.7101
# Epoch 5/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6880 - accuracy: 0.7085 - val_loss: 0.7230 - val_accuracy: 0.7043
# Epoch 6/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6876 - accuracy: 0.7096 - val_loss: 0.7227 - val_accuracy: 0.7074
# Epoch 7/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6874 - accuracy: 0.7092 - val_loss: 0.7221 - val_accuracy: 0.7083
# Epoch 8/100
# 227468/227468 [==============================] - 13s 58us/step - loss: 0.6875 - accuracy: 0.7098 - val_loss: 0.7222 - val_accuracy: 0.7116
# Epoch 9/100
# 227468/227468 [==============================] - 11s 46us/step - loss: 0.6873 - accuracy: 0.7102 - val_loss: 0.7220 - val_accuracy: 0.7107
# Epoch 10/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6879 - accuracy: 0.7093 - val_loss: 0.7236 - val_accuracy: 0.7087
# Epoch 11/100
# 227468/227468 [==============================] - 5s 20us/step - loss: 0.6875 - accuracy: 0.7105 - val_loss: 0.7225 - val_accuracy: 0.7096
# Epoch 12/100
# 227468/227468 [==============================] - 8s 37us/step - loss: 0.6872 - accuracy: 0.7094 - val_loss: 0.7234 - val_accuracy: 0.7058
# Epoch 13/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6873 - accuracy: 0.7095 - val_loss: 0.7217 - val_accuracy: 0.7114
# Epoch 14/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6874 - accuracy: 0.7093 - val_loss: 0.7237 - val_accuracy: 0.7085
# Epoch 15/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6873 - accuracy: 0.7097 - val_loss: 0.7228 - val_accuracy: 0.7103
# Epoch 16/100
# 227468/227468 [==============================] - 8s 36us/step - loss: 0.6873 - accuracy: 0.7094 - val_loss: 0.7242 - val_accuracy: 0.7093
# Epoch 17/100
# 227468/227468 [==============================] - 8s 36us/step - loss: 0.6870 - accuracy: 0.7098 - val_loss: 0.7217 - val_accuracy: 0.7102
# Epoch 18/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6874 - accuracy: 0.7101 - val_loss: 0.7221 - val_accuracy: 0.7101
# Epoch 19/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6872 - accuracy: 0.7103 - val_loss: 0.7220 - val_accuracy: 0.7124
# Epoch 20/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6871 - accuracy: 0.7108 - val_loss: 0.7226 - val_accuracy: 0.7037
# Epoch 21/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6873 - accuracy: 0.7107 - val_loss: 0.7224 - val_accuracy: 0.7103
# Epoch 22/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6871 - accuracy: 0.7116 - val_loss: 0.7247 - val_accuracy: 0.7027
# Epoch 23/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6870 - accuracy: 0.7112 - val_loss: 0.7220 - val_accuracy: 0.7115
# Epoch 24/100
# 227468/227468 [==============================] - 7s 33us/step - loss: 0.6869 - accuracy: 0.7109 - val_loss: 0.7228 - val_accuracy: 0.7036
# Epoch 25/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6872 - accuracy: 0.7116 - val_loss: 0.7230 - val_accuracy: 0.7075
# Epoch 26/100
# 227468/227468 [==============================] - 12s 54us/step - loss: 0.6868 - accuracy: 0.7120 - val_loss: 0.7223 - val_accuracy: 0.7117
# Epoch 27/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6871 - accuracy: 0.7110 - val_loss: 0.7220 - val_accuracy: 0.7118
# Epoch 28/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6870 - accuracy: 0.7119 - val_loss: 0.7225 - val_accuracy: 0.7143
# Epoch 29/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6868 - accuracy: 0.7139 - val_loss: 0.7224 - val_accuracy: 0.7135
# Epoch 30/100
# 227468/227468 [==============================] - 12s 55us/step - loss: 0.6867 - accuracy: 0.7136 - val_loss: 0.7221 - val_accuracy: 0.7130
# Epoch 31/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6868 - accuracy: 0.7126 - val_loss: 0.7223 - val_accuracy: 0.7151
# Epoch 32/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6866 - accuracy: 0.7139 - val_loss: 0.7217 - val_accuracy: 0.7142
# Epoch 33/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6867 - accuracy: 0.7147 - val_loss: 0.7225 - val_accuracy: 0.7121
# Epoch 34/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6868 - accuracy: 0.7150 - val_loss: 0.7237 - val_accuracy: 0.7120
# Epoch 35/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6866 - accuracy: 0.7154 - val_loss: 0.7221 - val_accuracy: 0.7106
# Epoch 36/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6865 - accuracy: 0.7147 - val_loss: 0.7243 - val_accuracy: 0.7072
# Epoch 37/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6866 - accuracy: 0.7143 - val_loss: 0.7223 - val_accuracy: 0.7172
# Epoch 38/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6864 - accuracy: 0.7153 - val_loss: 0.7224 - val_accuracy: 0.7155
# Epoch 39/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6867 - accuracy: 0.7156 - val_loss: 0.7290 - val_accuracy: 0.6979
# Epoch 40/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6866 - accuracy: 0.7153 - val_loss: 0.7220 - val_accuracy: 0.7175
# Epoch 41/100
# 227468/227468 [==============================] - 11s 50us/step - loss: 0.6867 - accuracy: 0.7159 - val_loss: 0.7239 - val_accuracy: 0.7094
# Epoch 42/100
# 227468/227468 [==============================] - 11s 51us/step - loss: 0.6863 - accuracy: 0.7159 - val_loss: 0.7222 - val_accuracy: 0.7139
# Epoch 43/100
# 227468/227468 [==============================] - 12s 51us/step - loss: 0.6860 - accuracy: 0.7167 - val_loss: 0.7282 - val_accuracy: 0.6982
# Epoch 44/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6868 - accuracy: 0.7147 - val_loss: 0.7239 - val_accuracy: 0.7063
# Epoch 45/100
# 227468/227468 [==============================] - 7s 30us/step - loss: 0.6863 - accuracy: 0.7168 - val_loss: 0.7221 - val_accuracy: 0.7129
# Epoch 46/100
# 227468/227468 [==============================] - 12s 52us/step - loss: 0.6862 - accuracy: 0.7155 - val_loss: 0.7232 - val_accuracy: 0.7202
# Epoch 47/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6867 - accuracy: 0.7154 - val_loss: 0.7218 - val_accuracy: 0.7136
# Epoch 48/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6867 - accuracy: 0.7164 - val_loss: 0.7219 - val_accuracy: 0.7197
# Epoch 49/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6862 - accuracy: 0.7168 - val_loss: 0.7237 - val_accuracy: 0.7126
# Epoch 50/100
# 227468/227468 [==============================] - 8s 37us/step - loss: 0.6861 - accuracy: 0.7165 - val_loss: 0.7239 - val_accuracy: 0.7169
# Epoch 51/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6862 - accuracy: 0.7152 - val_loss: 0.7233 - val_accuracy: 0.7097
# Epoch 52/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6865 - accuracy: 0.7160 - val_loss: 0.7215 - val_accuracy: 0.7175
# Epoch 53/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6862 - accuracy: 0.7167 - val_loss: 0.7216 - val_accuracy: 0.7199
# Epoch 54/100
# 227468/227468 [==============================] - 8s 37us/step - loss: 0.6860 - accuracy: 0.7168 - val_loss: 0.7218 - val_accuracy: 0.7180
# Epoch 55/100
# 227468/227468 [==============================] - 13s 58us/step - loss: 0.6862 - accuracy: 0.7166 - val_loss: 0.7232 - val_accuracy: 0.7136
# Epoch 56/100
# 227468/227468 [==============================] - 12s 54us/step - loss: 0.6864 - accuracy: 0.7160 - val_loss: 0.7241 - val_accuracy: 0.7141
# Epoch 57/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6859 - accuracy: 0.7170 - val_loss: 0.7239 - val_accuracy: 0.7157
# Epoch 58/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6862 - accuracy: 0.7156 - val_loss: 0.7222 - val_accuracy: 0.7209
# Epoch 59/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.6863 - accuracy: 0.7159 - val_loss: 0.7249 - val_accuracy: 0.7172
# Epoch 60/100
# 227468/227468 [==============================] - 8s 35us/step - loss: 0.6860 - accuracy: 0.7167 - val_loss: 0.7219 - val_accuracy: 0.7179
# Epoch 61/100
# 227468/227468 [==============================] - 8s 35us/step - loss: 0.6862 - accuracy: 0.7166 - val_loss: 0.7214 - val_accuracy: 0.7155
# Epoch 62/100
# 227468/227468 [==============================] - 10s 46us/step - loss: 0.6862 - accuracy: 0.7154 - val_loss: 0.7215 - val_accuracy: 0.7143
# Epoch 63/100
# 227468/227468 [==============================] - 9s 40us/step - loss: 0.6860 - accuracy: 0.7168 - val_loss: 0.7211 - val_accuracy: 0.7187
# Epoch 64/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6861 - accuracy: 0.7166 - val_loss: 0.7237 - val_accuracy: 0.7151
# Epoch 65/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6861 - accuracy: 0.7158 - val_loss: 0.7222 - val_accuracy: 0.7138
# Epoch 66/100
# 227468/227468 [==============================] - 13s 55us/step - loss: 0.6867 - accuracy: 0.7163 - val_loss: 0.7212 - val_accuracy: 0.7192
# Epoch 67/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6859 - accuracy: 0.7157 - val_loss: 0.7223 - val_accuracy: 0.7181
# Epoch 68/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6861 - accuracy: 0.7167 - val_loss: 0.7213 - val_accuracy: 0.7174
# Epoch 69/100
# 227468/227468 [==============================] - 11s 48us/step - loss: 0.6862 - accuracy: 0.7159 - val_loss: 0.7227 - val_accuracy: 0.7164
# Epoch 70/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6861 - accuracy: 0.7155 - val_loss: 0.7217 - val_accuracy: 0.7190
# Epoch 71/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6860 - accuracy: 0.7165 - val_loss: 0.7219 - val_accuracy: 0.7121
# Epoch 72/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6857 - accuracy: 0.7162 - val_loss: 0.7220 - val_accuracy: 0.7153
# Epoch 73/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6860 - accuracy: 0.7162 - val_loss: 0.7220 - val_accuracy: 0.7181
# Epoch 74/100
# 227468/227468 [==============================] - 6s 26us/step - loss: 0.6865 - accuracy: 0.7159 - val_loss: 0.7226 - val_accuracy: 0.7112
# Epoch 75/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6857 - accuracy: 0.7159 - val_loss: 0.7229 - val_accuracy: 0.7155
# Epoch 76/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6858 - accuracy: 0.7165 - val_loss: 0.7211 - val_accuracy: 0.7164
# Epoch 77/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6861 - accuracy: 0.7160 - val_loss: 0.7223 - val_accuracy: 0.7153
# Epoch 78/100
# 227468/227468 [==============================] - 13s 56us/step - loss: 0.6861 - accuracy: 0.7162 - val_loss: 0.7229 - val_accuracy: 0.7154
# Epoch 79/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6858 - accuracy: 0.7161 - val_loss: 0.7215 - val_accuracy: 0.7136
# Epoch 80/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6863 - accuracy: 0.7161 - val_loss: 0.7230 - val_accuracy: 0.7194
# Epoch 81/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6867 - accuracy: 0.7159 - val_loss: 0.7226 - val_accuracy: 0.7149
# Epoch 82/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6859 - accuracy: 0.7169 - val_loss: 0.7250 - val_accuracy: 0.7133
# Epoch 83/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6857 - accuracy: 0.7166 - val_loss: 0.7236 - val_accuracy: 0.7109
# Epoch 84/100
# 227468/227468 [==============================] - 9s 41us/step - loss: 0.6857 - accuracy: 0.7167 - val_loss: 0.7218 - val_accuracy: 0.7172
# Epoch 85/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6862 - accuracy: 0.7166 - val_loss: 0.7225 - val_accuracy: 0.7160
# Epoch 86/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6858 - accuracy: 0.7166 - val_loss: 0.7213 - val_accuracy: 0.7201
# Epoch 87/100
# 227468/227468 [==============================] - 11s 49us/step - loss: 0.6860 - accuracy: 0.7165 - val_loss: 0.7225 - val_accuracy: 0.7172
# Epoch 88/100
# 227468/227468 [==============================] - 12s 53us/step - loss: 0.6859 - accuracy: 0.7156 - val_loss: 0.7215 - val_accuracy: 0.7152
# Epoch 89/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.6856 - accuracy: 0.7162 - val_loss: 0.7244 - val_accuracy: 0.6956
# Epoch 90/100
# 227468/227468 [==============================] - 11s 47us/step - loss: 0.6863 - accuracy: 0.7157 - val_loss: 0.7242 - val_accuracy: 0.7100
# Epoch 91/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6858 - accuracy: 0.7161 - val_loss: 0.7235 - val_accuracy: 0.7107
# Epoch 92/100
# 227468/227468 [==============================] - 10s 43us/step - loss: 0.6859 - accuracy: 0.7162 - val_loss: 0.7260 - val_accuracy: 0.6985
# Epoch 93/100
# 227468/227468 [==============================] - 8s 36us/step - loss: 0.6861 - accuracy: 0.7166 - val_loss: 0.7228 - val_accuracy: 0.7115
# Epoch 94/100
# 227468/227468 [==============================] - 9s 39us/step - loss: 0.6857 - accuracy: 0.7162 - val_loss: 0.7258 - val_accuracy: 0.7024
# Epoch 95/100
# 227468/227468 [==============================] - 10s 44us/step - loss: 0.6864 - accuracy: 0.7152 - val_loss: 0.7213 - val_accuracy: 0.7184
# Epoch 96/100
# 227468/227468 [==============================] - 9s 38us/step - loss: 0.6855 - accuracy: 0.7161 - val_loss: 0.7302 - val_accuracy: 0.7158
# Epoch 97/100
# 227468/227468 [==============================] - 9s 42us/step - loss: 0.6859 - accuracy: 0.7169 - val_loss: 0.7257 - val_accuracy: 0.7132
# Epoch 98/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6856 - accuracy: 0.7167 - val_loss: 0.7213 - val_accuracy: 0.7157
# Epoch 99/100
# 227468/227468 [==============================] - 10s 42us/step - loss: 0.6856 - accuracy: 0.7160 - val_loss: 0.7226 - val_accuracy: 0.7174
# Epoch 100/100
# 227468/227468 [==============================] - 10s 45us/step - loss: 0.6859 - accuracy: 0.7165 - val_loss: 0.7232 - val_accuracy: 0.7161

# %%
autoencoder = load_model('autoencoder_fraud.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-6fa258810efb> in <module>
# ----> 1 autoencoder = load_model('autoencoder_fraud.h5')
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     271     if model_config is None:
#     272         raise ValueError('No model found in config.')
# --> 273     model_config = json.loads(model_config.decode('utf-8'))
#     274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
autoencoder = load_model('autoencoder_fraud.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6fa258810efb> in <module>
# ----> 1 autoencoder = load_model('autoencoder_fraud.h5')
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# ~\Anaconda3\lib\site-packages\keras\engine\saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     271     if model_config is None:
#     272         raise ValueError('No model found in config.')
# --> 273     model_config = json.loads(model_config.decode('utf-8'))
#     274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %%
test_x_predictions = autoencoder.predict(test_x)
mse = np.mean(np.power(test_x - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_y})
error_df.describe()
# Out:
#        Reconstruction_error    True_class
# count          56962.000000  56962.000000
# mean               0.723115      0.002019
# std                3.124576      0.044887
# min                0.044002      0.000000
# 25%                0.242865      0.000000
# 50%                0.396353      0.000000
# 75%                0.629764      0.000000
# max              208.784618      1.000000

# %%
false_pos_rate, true_pos_rate, thresholds = roc_curve(error_df.True_class, error_df.Reconstruction_error)
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth=5, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class, error_df.Reconstruction_error)
plt.plot(recall_rt, precision_rt, linewidth=5, label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=5)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=5)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %%
threshold_fixed = 5
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.True_class, pred_y)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
model3=df.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f412e98673c3> in <module>
# ----> 1 model3=df.fit(train_x,train_y)
#
# NameError: name 'df' is not defined

# %%
from sklearn.tree import autoencoders
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-cd3eaf585c61> in <module>
# ----> 1 from sklearn.tree import autoencoders
#
# ImportError: cannot import name 'autoencoders'

# %%
from sklearn.tree import autoencoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-0d89f4dc3200> in <module>
# ----> 1 from sklearn.tree import autoencoder
#
# ImportError: cannot import name 'autoencoder'
